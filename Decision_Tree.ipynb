# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
diab=pd.read_csv("C:\\Users\\user\\Downloads\\diabetes.csv")

# %%
diab.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            2      138             62             35        0  33.6
# 1            0       84             82             31      125  38.2
# 2            0      145              0              0        0  44.2
# 3            0      135             68             42      250  42.3
# 4            1      139             62             41      480  40.7
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.127   47        1
# 1                     0.233   23        0
# 2                     0.630   31        1
# 3                     0.365   24        1
# 4                     0.536   21        0

# %%
diab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
# Pregnancies                 2000 non-null int64
# Glucose                     2000 non-null int64
# BloodPressure               2000 non-null int64
# SkinThickness               2000 non-null int64
# Insulin                     2000 non-null int64
# BMI                         2000 non-null float64
# DiabetesPedigreeFunction    2000 non-null float64
# Age                         2000 non-null int64
# Outcome                     2000 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 140.7 KB

# %%
diab.isnull().values.any()
# Out:
# False

# %%
diab.describe()
# Out:
#        Pregnancies      Glucose  BloodPressure  SkinThickness      Insulin  \
# count  2000.000000  2000.000000    2000.000000    2000.000000  2000.000000
# mean      3.703500   121.182500      69.145500      20.935000    80.254000
# std       3.306063    32.068636      19.188315      16.103243   111.180534
# min       0.000000     0.000000       0.000000       0.000000     0.000000
# 25%       1.000000    99.000000      63.500000       0.000000     0.000000
# 50%       3.000000   117.000000      72.000000      23.000000    40.000000
# 75%       6.000000   141.000000      80.000000      32.000000   130.000000
# max      17.000000   199.000000     122.000000     110.000000   744.000000
#
#                BMI  DiabetesPedigreeFunction          Age      Outcome
# count  2000.000000               2000.000000  2000.000000  2000.000000
# mean     32.193000                  0.470930    33.090500     0.342000
# std       8.149901                  0.323553    11.786423     0.474498
# ...

# %%
sns.heatmap(diab.isnull(),cmap="viridis")

# %%
sns.pairplot(diab)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(diab.drop("Outcome",axis=1),diab['Outcome'],test_size=0.3)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt=DecisionTreeClassifier()

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
y_predict=dt.predict(x_test)

# %%
y_test.head()
# Out:
# 1011    0
# 1476    1
# 56      1
# 1232    0
# 1949    1
# Name: Outcome, dtype: int64

# %%
y_predict[0:5]
# Out:
# array([0, 1, 1, 0, 1], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,y_predict)
# Out:
# array([[395,   5],
#        [ 10, 190]], dtype=int64)

# %%
(400+182)/(400+7+11+182)
# Out:
# 0.97

# %%
#0.97 accuracy approzimately near to 1
